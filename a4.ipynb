# %%
pip install pandas matplotlib numpy seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
covid1 =pd.read_csv('covid_vaccine_statewise.csv')

# %%
covid2 = covid1[covid1['State'] != 'India']
# print()
covid2.head(len(covid2))
# Out:
#       Updated On                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
# ...          ...                          ...                       ...
# 7840  11/08/2021                  West Bengal                       NaN
# 7841  12/08/2021                  West Bengal                       NaN
# 7842  13/08/2021                  West Bengal                       NaN
# 7843  14/08/2021                  West Bengal                       NaN
# 7844  15/08/2021                  West Bengal                       NaN
#
#       Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
covid2.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.415000e+03  7.415000e+03   7415.000000
# mean               4.720335e+06  2.462739e+05   1173.123264
# std                7.877656e+06  4.724983e+05   1557.088007
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.287485e+05  5.755000e+03     67.000000
# 50%                7.517130e+05  3.736200e+04    545.000000
# 75%                6.099970e+06  3.052925e+05   1563.500000
# max                5.444772e+07  8.171330e+06  12350.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.415000e+03              7.415000e+03
# mean              3.808916e+06              9.114184e+05
# std               6.299814e+06              1.636821e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.081580e+05              1.235100e+04
# 50%               6.219820e+05              1.276590e+05
# ...

# %%
state_groupby = covid2.groupby(by='State')['First Dose Administered'].sum()
state_groupby.head(100)
# Out:
# State
# Andaman and Nicobar Islands                 1.642585e+07
# Andhra Pradesh                              1.232861e+09
# Arunachal Pradesh                           4.900498e+07
# Assam                                       5.856002e+08
# Bihar                                       1.470503e+09
# Chandigarh                                  4.470310e+07
# Chhattisgarh                                7.960029e+08
# Dadra and Nagar Haveli and Daman and Diu    3.359506e+07
# Delhi                                       6.243395e+08
# Goa                                         7.599137e+07
# Gujarat                                     2.131646e+09
# Haryana                                     7.557984e+08
# Himachal Pradesh                            3.162940e+08
# Jammu and Kashmir                           4.101018e+08
# Jharkhand                                   6.036737e+08
# Karnataka                                   1.873330e+09
# ...

# %%
plt.figure(figsize=(8, 6))
state_groupby.plot(kind='bar')
plt.title('Total Number of First Doses Administered by State')
plt.xlabel('State')
plt.ylabel('Total Number of First Doses')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
state_groupby1 = covid2.groupby(by='State')['Second Dose Administered'].std()
state_groupby1.head(100)
# Out:
# State
# Andaman and Nicobar Islands                 2.812673e+04
# Andhra Pradesh                              1.732045e+06
# Arunachal Pradesh                           5.264362e+04
# Assam                                       6.250273e+05
# Bihar                                       1.230604e+06
# Chandigarh                                  5.902525e+04
# Chhattisgarh                                7.573578e+05
# Dadra and Nagar Haveli and Daman and Diu    2.397146e+04
# Delhi                                       8.832993e+05
# Goa                                         8.217012e+04
# Gujarat                                     2.717903e+06
# Haryana                                     8.026250e+05
# Himachal Pradesh                            3.916815e+05
# Jammu and Kashmir                           4.014045e+05
# Jharkhand                                   5.637212e+05
# Karnataka                                   2.105080e+06
# ...

# %%
plt.figure(figsize=(8, 6))
state_groupby1.plot(kind='bar', color='green')  # Using a different color for second dose
plt.title('Total Number of Second Doses Administered by State')
plt.xlabel('State')
plt.ylabel('Total Number of Second Doses')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
specific_date_str = '09/08/2021'

specific_date_entries = covid2[covid2['Updated On'] == specific_date_str].copy()

total_male_doses_on_specific_date = specific_date_entries['Male (Doses Administered)'].sum()

print(total_male_doses_on_specific_date)
# Out:
# 270163622.0

# %% [markdown]
# # Number of persons state wise vaccinated for first dose in India

# %%
state_groupby_male_doses = specific_date_entries.groupby('State')['Male (Doses Administered)'].sum()
plt.figure(figsize=(8, 6))
state_groupby_male_doses.plot(kind='bar', color='red')
plt.title('Total Male Doses Administered by State')
plt.xlabel('State')
plt.ylabel('Total Male Doses')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
specific_date_str = '09/08/2021'

specific_date_entries = covid2[covid2['Updated On'] == specific_date_str].copy()

total_female_doses_on_specific_date = specific_date_entries['Female (Doses Administered)'].sum()

print(total_female_doses_on_specific_date)
# Out:
# 239518609.0

# %%
state_groupby_female_doses = specific_date_entries.groupby('State')['Female (Doses Administered)'].sum()
plt.figure(figsize=(8, 6))
state_groupby_female_doses.plot(kind='bar', color='black')
plt.title('Total Female Doses Administered by State')
plt.xlabel('State')
plt.ylabel('Total Female Doses')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# !jupyter nbconvert --to html a4.ipynb
# Out:
# [NbConvertApp] Converting notebook a4.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 7 image(s).
# [NbConvertApp] Writing 956571 bytes to a4.html

# %% [markdown]
# # Number of deaths , cured , and Confirmed

# %%
covid1 =pd.read_csv('covid_vaccine_statewise.csv')
covid_deaths = pd.read_csv('covid_19_india.csv')
covid_test = pd.read_csv('StatewiseTestingDetails.csv')

# %%
covid_deaths.head(len(covid_deaths))
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
D_stateGroupby = covid_deaths.groupby(by='State/UnionTerritory')['Deaths'].sum()
D_stateGroupby.head(100)
# Out:
# State/UnionTerritory
# Andaman and Nicobar Islands                    27136
# Andhra Pradesh                               2939367
# Arunachal Pradesh                              26799
# Assam                                         638323
# Bihar                                        1093466
# Bihar****                                      18881
# Cases being reassigned to states                   0
# Chandigarh                                    147694
# Chhattisgarh                                 2063920
# Dadra and Nagar Haveli                             8
# Dadra and Nagar Haveli and Daman and Diu        1014
# Daman & Diu                                        0
# Delhi                                        4943294
# Goa                                           447801
# Gujarat                                      2219448
# Haryana                                      1502799
# Himachal Pradesh                              491348
# ...

# %%
plt.figure(figsize=(8, 6))
D_stateGroupby.plot(kind='bar')
plt.title('TDeaths')
plt.xlabel('State')
plt.ylabel('States')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
confirm_stateGroupby = covid_deaths.groupby(by='State/UnionTerritory')['Confirmed'].sum()
confirm_stateGroupby.head(100)
# Out:
# State/UnionTerritory
# Andaman and Nicobar Islands                    1938498
# Andhra Pradesh                               392432753
# Arunachal Pradesh                              7176907
# Assam                                         99837011
# Bihar                                        132231166
# Bihar****                                      1430909
# Cases being reassigned to states                345565
# Chandigarh                                    10858627
# Chhattisgarh                                 163776262
# Dadra and Nagar Haveli                           20722
# Dadra and Nagar Haveli and Daman and Diu       1938632
# Daman & Diu                                          2
# Delhi                                        287227765
# Goa                                           28240159
# Gujarat                                      143420082
# Haryana                                      134347285
# Himachal Pradesh                              30033289
# ...

# %%
plt.figure(figsize=(8, 6))
confirm_stateGroupby.plot(kind='bar')
plt.title('Confirmed')
plt.xlabel('State')
plt.ylabel('States')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
cured_stateGroupby = covid_deaths.groupby(by='State/UnionTerritory')['Cured'].sum()
cured_stateGroupby.head(100)
# Out:
# State/UnionTerritory
# Andaman and Nicobar Islands                    1848286
# Andhra Pradesh                               370426530
# Arunachal Pradesh                              6588149
# Assam                                         92678680
# Bihar                                        125122902
# Bihar****                                      1402468
# Cases being reassigned to states                     0
# Chandigarh                                    10117035
# Chhattisgarh                                 151609364
# Dadra and Nagar Haveli                           20352
# Dadra and Nagar Haveli and Daman and Diu       1841750
# Daman & Diu                                          0
# Delhi                                        273419887
# Goa                                           26027201
# Gujarat                                      132487127
# Haryana                                      126585342
# Himachal Pradesh                              27501110
# ...

# %%
plt.figure(figsize=(8, 6))
cured_stateGroupby.plot(kind='bar')
plt.title('Cured')
plt.xlabel('State')
plt.ylabel('States')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
covid_test.head(len(covid_test))
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive
# 0          12.0
# 1          27.0
# 2          33.0
# 3          33.0
# 4          33.0
# ...         ...
# ...

# %%
covid_test['Percent Positive'] = (covid_test['Positive'] / covid_test['TotalSamples']) * 100


print(covid_test[['State', 'TotalSamples', 'Positive', 'Percent Positive']])
# Out:
#                              State  TotalSamples  Positive  Percent Positive
# 0      Andaman and Nicobar Islands        1403.0      12.0          0.855310
# 1      Andaman and Nicobar Islands        2679.0      27.0          1.007839
# 2      Andaman and Nicobar Islands        2848.0      33.0          1.158708
# 3      Andaman and Nicobar Islands        3754.0      33.0          0.879062
# 4      Andaman and Nicobar Islands        6677.0      33.0          0.494234
# ...                            ...           ...       ...               ...
# 16331                  West Bengal    15999961.0       NaN               NaN
# 16332                  West Bengal    16045662.0       NaN               NaN
# 16333                  West Bengal    16092192.0       NaN               NaN
# 16334                  West Bengal    16122345.0       NaN               NaN
# 16335                  West Bengal    16162814.0       NaN               NaN
#
# [16336 rows x 4 columns]

# %%
plt.figure(figsize=(8, 6))
plt.bar(covid_test['State'], covid_test['Percent Positive'], color='skyblue')
plt.title('Percent Positive Rate by State')
plt.xlabel('State')
plt.ylabel('Percent Positive')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
covid2.head(len(covid2))
# Out:
#       Updated On                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
# ...          ...                          ...                       ...
# 7840  11/08/2021                  West Bengal                       NaN
# 7841  12/08/2021                  West Bengal                       NaN
# 7842  13/08/2021                  West Bengal                       NaN
# 7843  14/08/2021                  West Bengal                       NaN
# 7844  15/08/2021                  West Bengal                       NaN
#
#       Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
print(covid2.columns)
# Out:
# Index(['Updated On', 'State', 'Total Doses Administered', 'Sessions',
#        ' Sites ', 'First Dose Administered', 'Second Dose Administered',
#        'Male (Doses Administered)', 'Female (Doses Administered)',
#        'Transgender (Doses Administered)', ' Covaxin (Doses Administered)',
#        'CoviShield (Doses Administered)', 'Sputnik V (Doses Administered)',
#        'AEFI', '18-44 Years (Doses Administered)',
#        '45-60 Years (Doses Administered)', '60+ Years (Doses Administered)',
#        '18-44 Years(Individuals Vaccinated)',
#        '45-60 Years(Individuals Vaccinated)',
#        '60+ Years(Individuals Vaccinated)', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Individuals Vaccinated'],
#       dtype='object')

# %%
st_groupbyVC1 = covid2.groupby(by='State')[' Covaxin (Doses Administered)'].sum()
st_groupbyVC1.head(100)
# Out:
# State
# Andaman and Nicobar Islands                         0.0
# Andhra Pradesh                              263695249.0
# Arunachal Pradesh                                1820.0
# Assam                                       118720291.0
# Bihar                                       156807520.0
# Chandigarh                                     117678.0
# Chhattisgarh                                 57309565.0
# Dadra and Nagar Haveli and Daman and Diu         1072.0
# Delhi                                       218692040.0
# Goa                                           1469705.0
# Gujarat                                     307771021.0
# Haryana                                     129521424.0
# Himachal Pradesh                               106196.0
# Jammu and Kashmir                            10689044.0
# Jharkhand                                   101754584.0
# Karnataka                                   260352181.0
# Kerala                                      121110027.0
# ...

# %%
st_groupbyVC2 = covid2.groupby(by='State')['CoviShield (Doses Administered)'].sum()
st_groupbyVC2.head(100)
# Out:
# State
# Andaman and Nicobar Islands                 2.051143e+07
# Andhra Pradesh                              1.323987e+09
# Arunachal Pradesh                           6.080052e+07
# Assam                                       5.970823e+08
# Bihar                                       1.582600e+09
# Chandigarh                                  5.614530e+07
# Chhattisgarh                                9.095543e+08
# Dadra and Nagar Haveli and Daman and Diu    3.817282e+07
# Delhi                                       5.920689e+08
# Goa                                         9.065506e+07
# Gujarat                                     2.420791e+09
# Haryana                                     7.829140e+08
# Himachal Pradesh                            3.894229e+08
# Jammu and Kashmir                           4.850749e+08
# Jharkhand                                   6.233471e+08
# Karnataka                                   2.035228e+09
# ...

# %%
st_groupbyVC3 = covid2.groupby(by='State')['Sputnik V (Doses Administered)'].sum()
st_groupbyVC3.head(100)
# Out:
# State
# Andaman and Nicobar Islands                       0.0
# Andhra Pradesh                              1412491.0
# Arunachal Pradesh                                 0.0
# Assam                                         37342.0
# Bihar                                         61096.0
# Chandigarh                                        0.0
# Chhattisgarh                                 108656.0
# Dadra and Nagar Haveli and Daman and Diu          0.0
# Delhi                                       1017693.0
# Goa                                               0.0
# Gujarat                                      262837.0
# Haryana                                     1001912.0
# Himachal Pradesh                             140518.0
# Jammu and Kashmir                                 0.0
# Jharkhand                                    100747.0
# Karnataka                                   1186887.0
# Kerala                                       582603.0
# ...

# %%
specific_date_str = '09/08/2021'

specific_date_entries = covid2[covid2['Updated On'] == specific_date_str].copy()

total_spV = specific_date_entries['Sputnik V (Doses Administered)'].sum()

print(total_spV)
# Out:
# 588039.0

# %%
specific_date_str = '09/08/2021'

specific_date_entries = covid2[covid2['Updated On'] == specific_date_str].copy()

total_covsh = specific_date_entries['CoviShield (Doses Administered)'].sum()

print(total_covsh)
# Out:
# 446825051.0

# %%
specific_date_str = '09/08/2021'

specific_date_entries = covid2[covid2['Updated On'] == specific_date_str].copy()

total_covx = specific_date_entries[' Covaxin (Doses Administered)'].sum()

print(total_covx)
# Out:
# 62367416.0

# %%
vaccine_types = ['Sputnik V', 'CoviShield', 'Covaxin']
total_doses = [total_spV, total_covsh, total_covx]

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(total_doses, labels=vaccine_types, autopct='%1.1f%%', colors=['black', 'skyblue', 'orange'])
plt.title('Total Doses Administered for Each Vaccine Type on {}'.format(specific_date_str))
plt.show()
